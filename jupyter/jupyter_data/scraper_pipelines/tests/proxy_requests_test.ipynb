# %% [markdown]
# # Prueba de conexión a proxy

# %% [markdown]
# ** Abstracción de path para los módulos en utils **

# %%
import sys
import os

# Subimos un nivel para llegar a 'scraper_pipelines' y lo añadimos al path
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %% [markdown]
# ## Código de prueba de proxy

# %%
import os
from scrapers_utils import BaseScraper
# 1. Definimos la URL de Decodo (esto lo puedes sacar de tus variables de entorno)

user = os.getenv('DECODO_USERNAME')
password = os.getenv('DECODO_PASSWORD')
proxy_url = f"http://{user}:{password}@mx.decodo.com:20001"

# 2. Ejecutamos el test estático de la clase
is_active = BaseScraper.test_proxy(proxy_url)

if is_active:
    print("🚀 Todo listo para iniciar el navegador.")
else:
    print("❌ Revisa tus credenciales o el estado de Decodo.")
# Out:
# Testing Decodo proxy connection...
# Proxy Active! Current IP: None in {'name': 'Mexico', 'code': 'MX', 'continent': 'North America'}
# IP_DATA:
# {'browser': {'name': 'python-requests', 'version': '2.31.0'}, 'platform': {'name': '', 'os': '', 'type': 'desktop'}, 'engine': {'name': '', 'version': ''}, 'isp': {'asn': 8151, 'isp': 'Telmex DSL', 'organization': 'Telmex DSL', 'domain': ''}, 'city': {'name': 'Chihuahua City', 'code': 'CHH', 'zip_code': '31034', 'state': 'Chihuahua', 'time_zone': 'America/Chihuahua', 'longitude': -106.229, 'latitude': 28.998}, 'proxy': {'ip': '189.237.91.132'}, 'country': {'name': 'Mexico', 'code': 'MX', 'continent': 'North America'}}
#
# ...
# 🚀 Todo listo para iniciar el navegador.
