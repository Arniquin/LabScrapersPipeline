# %%
import sys
import os

# Subimos un nivel para llegar a 'scraper_pipelines' y lo añadimos al path
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from pipeline_utils import RunManager

# %%
run_manager = RunManager("example_client","example_pipeline")

# %%
run_id = run_manager.start_run()
# Out:
# ------------------------HEADERS-------------------------
# {'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive', 'X-Internal-Secret': 'mexico_dev_secret_2026_xyz', 'Content-Type': 'application/json_TESTS', 'Content-Length': '107'}
# ------------------------END HEADERS-------------------------

# %%
print(run_id)
# Out:
# 8a7a0573-5ef7-4554-9af9-f21a81deef3c

# %%
run_manager.step = CLEANING
